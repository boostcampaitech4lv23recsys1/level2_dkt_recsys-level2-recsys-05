# %% [markdown]
# # 대회 설명
#
# - 해당 Deep Knowledge Tracing(DKT) 대회는 사용자의 과거 문제정답 여부에 따른 다음 문제에 대한 정답 여부를 예측해야한다.
# - 사용자별 다음 문제를 맞출지 못맞출지 예측을 해야한다.

# %%
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as spst

from eda_tool import null_check, nunique, count_plot, kde_hist_plot, extract_datetime, extract_testId, extract_assessmentItemID
from sklearn.cluster import DBSCAN
from sklearn.metrics import accuracy_score, roc_auc_score
from catboost import CatBoostClassifier
from statsmodels.tsa.seasonal import STL
from statsmodels.api import Logit
from tqdm import tqdm
import random
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('mode.chained_assignment',  None)
seed = 777
random.seed(seed)

# %%
train_df = pd.read_csv("../data/train_data.csv")
test_df = pd.read_csv("../data/test_data.csv")
train_df
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2266581    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2266582    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2266583    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2266584    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2266585    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag
# 0                7224
# 1                7225
# 2                7225
# 3                7225
# 4                7225
# ...               ...
# 2266581           438
# 2266582          8836
# 2266583          8836
# 2266584          8836
# 2266585          8836
#
# [2266586 rows x 6 columns]

# %%
total = pd.concat([train_df, test_df.loc[test_df['answerCode'] != -1]], axis=0)
total = total.sort_values(by=["userID", "Timestamp",]).reset_index(drop=True)
total
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag
# 0                7224
# 1                7225
# 2                7225
# 3                7225
# 4                7225
# ...               ...
# 2525951           438
# 2525952          8836
# 2525953          8836
# 2525954          8836
# 2525955          8836
#
# [2525956 rows x 6 columns]

# %% [markdown]
# ### Clustering

# %%
total = extract_datetime(total)
total = extract_testId(total)
total = extract_assessmentItemID(total)
total
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  month  day  hour  minute  second  testClass  testCode  \
# 0                7224      3   24     0      17      11          6         1
# 1                7225      3   24     0      17      14          6         1
# 2                7225      3   24     0      17      22          6         1
# 3                7225      3   24     0      17      29          6         1
# 4                7225      3   24     0      17      36          6         1
# ...               ...    ...  ...   ...     ...     ...        ...       ...
# 2525951           438      6    5     6      50      21          3        71
# 2525952          8836      8   21     1       6      39          4       165
# 2525953          8836      8   21     1       6      50          4       165
# 2525954          8836      8   21     1       7      36          4       165
# 2525955          8836      8   21     1       8      49          4       165
#
#          assessmentItemCode
# 0                         1
# 1                         2
# 2                         3
# 3                         4
# 4                         5
# ...                     ...
# 2525951                   5
# 2525952                   1
# 2525953                   2
# 2525954                   3
# 2525955                   4
#
# [2525956 rows x 14 columns]

# %%
for_clustering = total.drop(['assessmentItemID', 'testId', 'Timestamp'], axis=1)
# for_clustering = total[['userID', 'KnowledgeTag', 'testCode', 'answerCode']]
for_clustering
# Out:
#          userID  answerCode  KnowledgeTag  month  day  hour  minute  second  \
# 0             0           1          7224      3   24     0      17      11
# 1             0           1          7225      3   24     0      17      14
# 2             0           1          7225      3   24     0      17      22
# 3             0           1          7225      3   24     0      17      29
# 4             0           1          7225      3   24     0      17      36
# ...         ...         ...           ...    ...  ...   ...     ...     ...
# 2525951    7441           0           438      6    5     6      50      21
# 2525952    7441           1          8836      8   21     1       6      39
# 2525953    7441           1          8836      8   21     1       6      50
# 2525954    7441           1          8836      8   21     1       7      36
# 2525955    7441           1          8836      8   21     1       8      49
#
#          testClass  testCode  assessmentItemCode
# 0                6         1                   1
# 1                6         1                   2
# 2                6         1                   3
# 3                6         1                   4
# 4                6         1                   5
# ...            ...       ...                 ...
# 2525951          3        71                   5
# 2525952          4       165                   1
# 2525953          4       165                   2
# 2525954          4       165                   3
# 2525955          4       165                   4
#
# [2525956 rows x 11 columns]

# %%
from kmodes.kmodes import KModes
km_cao = KModes(n_clusters=10, init = "Cao", n_init = 1, verbose=1)
fitClusters_cao = km_cao.fit_predict(for_clustering.drop(['answerCode'], axis=1))
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 7070, cost: 20753286.0

# %%
fitClusters_cao

# %%
cost = []
for num_clusters in list(range(2,11)):
    kmode = KModes(n_clusters=num_clusters, init = "Cao", n_init = 1, verbose=1)
    kmode.fit_predict(for_clustering.drop(['answerCode'], axis=1))
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 10632, cost: 22759174.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2841, cost: 22114351.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4051, cost: 21696382.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4127, cost: 21408385.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4637, cost: 21254026.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 5042, cost: 21114750.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 5384, cost: 20989951.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 7018, cost: 20861961.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 7070, cost: 20753286.0

# %%
y = np.array([i for i in range(2,11,1)])
plt.plot(y,cost)

# %%
km_cao = KModes(n_clusters=5, init = "Cao", n_init = 1, verbose=1)
fitClusters_cao = km_cao.fit_predict(for_clustering.drop(['answerCode'], axis=1))
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4127, cost: 21408385.0

# %%
clustering = for_clustering.drop(['answerCode'], axis=1).reset_index(drop=True)
clustersDf = pd.DataFrame(fitClusters_cao)
clustersDf.columns = ['cluster_predicted']
combinedDf = pd.concat([clustering, clustersDf], axis = 1).reset_index(drop=True)
combinedDf
# Out:
#          userID  KnowledgeTag  month  day  hour  minute  second  testClass  \
# 0             0           556      2   23     0      17      11          5
# 1             0           557      2   23     0      17      14          5
# 2             0           557      2   23     0      17      22          5
# 3             0           557      2   23     0      17      29          5
# 4             0           557      2   23     0      17      36          5
# ...         ...           ...    ...  ...   ...     ...     ...        ...
# 2525951    7441            58      5    4     6      50      21          2
# 2525952    7441           720      7   20     1       6      39          3
# 2525953    7441           720      7   20     1       6      50          3
# 2525954    7441           720      7   20     1       7      36          3
# 2525955    7441           720      7   20     1       8      49          3
#
#          testCode  assessmentItemCode  cluster_predicted
# 0               0                   0                  0
# 1               0                   1                  2
# 2               0                   2                  1
# 3               0                   3                  3
# 4               0                   4                  3
# ...           ...                 ...                ...
# 2525951        70                   4                  4
# 2525952       164                   0                  0
# 2525953       164                   1                  2
# 2525954       164                   2                  1
# 2525955       164                   3                  1
#
# [2525956 rows x 11 columns]

# %%
cluster_0 = combinedDf[combinedDf['cluster_predicted'] == 0]
cluster_1 = combinedDf[combinedDf['cluster_predicted'] == 1]
cluster_2 = combinedDf[combinedDf['cluster_predicted'] == 2]
cluster_3 = combinedDf[combinedDf['cluster_predicted'] == 3]
cluster_4 = combinedDf[combinedDf['cluster_predicted'] == 4]
# cluster_5 = combinedDf[combinedDf['cluster_predicted'] == 5]
# cluster_6 = combinedDf[combinedDf['cluster_predicted'] == 6]
# cluster_7 = combinedDf[combinedDf['cluster_predicted'] == 7]
# cluster_8 = combinedDf[combinedDf['cluster_predicted'] == 8]
# cluster_9 = combinedDf[combinedDf['cluster_predicted'] == 9]

# %%
tmp = pd.concat([combinedDf, for_clustering['answerCode']], axis=1)

# %%
ct = pd.crosstab(tmp['cluster_predicted'], tmp['answerCode'], normalize='index')
new_ct = pd.concat([ct, pd.DataFrame(ct.index)], axis=1)
new_ct
# Out:
#           0         1  cluster_predicted
# 0  0.360458  0.639542                  0
# 1  0.338425  0.661575                  1
# 2  0.298843  0.701157                  2
# 3  0.344037  0.655963                  3
# 4  0.389242  0.610758                  4

# %%
sns.barplot(data= new_ct, x= "cluster_predicted", y=1)
# Out:
# <AxesSubplot: xlabel='cluster_predicted', ylabel='1'>

# %%
plt.subplots(figsize = (20,5))
# sns.countplot(x=tmp['cluster_predicted'], hue=tmp['answerCode'])
# sns.countplot(x=tmp['answerCode'], hue=tmp['cluster_predicted'])
sns.histplot(x=tmp['cluster_predicted'], hue=tmp['answerCode'], stat='percent')
plt.show()

# %%
plt.subplots(figsize = (20,5))
sns.countplot(x=combinedDf['userID'],order=combinedDf['userID'].value_counts().index,hue=combinedDf['cluster_predicted'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
# sns.countplot(x=combinedDf['KnowledgeTag'],order=combinedDf['KnowledgeTag'].value_counts().index,hue=combinedDf['cluster_predicted'])
sns.countplot(x=combinedDf['cluster_predicted'],hue=combinedDf['KnowledgeTag'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
sns.countplot(x=combinedDf['month'],order=combinedDf['month'].value_counts().index,hue=combinedDf['cluster_predicted'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
sns.countplot(x=combinedDf['day'],order=combinedDf['day'].value_counts().index,hue=combinedDf['cluster_predicted'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
sns.countplot(x=combinedDf['hour'],order=combinedDf['hour'].value_counts().index,hue=combinedDf['cluster_predicted'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
sns.countplot(x=combinedDf['minute'],order=combinedDf['minute'].value_counts().index,hue=combinedDf['cluster_predicted'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
# sns.countplot(x=combinedDf['second'],order=combinedDf['second'].value_counts().index,hue=combinedDf['cluster_predicted'])
sns.countplot(x=combinedDf['cluster_predicted'],hue=combinedDf['second'])
plt.show()

# %%
combinedDf.loc[(combinedDf['second'] == 35) & (combinedDf['cluster_predicted'] == 0)]
# Out:
#          userID  KnowledgeTag  month  day  hour  minute  second  testClass  \
# 45            0            89      3   15     3       8      35          5
# 90            0           187      3   24    22      22      35          7
# 226           0           413      5    2    16      11      35          7
# 271           0           110      5   10     2      23      35          5
# 484           0             3      8    0    20       9      35          7
# ...         ...           ...    ...  ...   ...     ...     ...        ...
# 2525469    7412           696      8    7     1      35      35          3
# 2525643    7422           221      9   22     7      13      35          2
# 2525779    7430           261      7   16     3      17      35          3
# 2525896    7437           558      4   21     1      53      35          5
# 2525937    7440           595      8   22     9      19      35          2
#
#          testCode  assessmentItemCode  cluster_predicted
# 45             15                   5                  0
# 90              9                   5                  0
# 226            36                   2                  0
# 271            57                   2                  0
# 484            79                   7                  0
# ...           ...                 ...                ...
# 2525469       102                   3                  0
# 2525643       170                   1                  0
# 2525779        96                   3                  0
# 2525896         2                   2                  0
# 2525937       135                   0                  0
#
# [31545 rows x 11 columns]

# %%
plt.subplots(figsize = (20,5))
# sns.countplot(x=combinedDf['testClass'],order=combinedDf['testClass'].value_counts().index,hue=combinedDf['cluster_predicted'])
sns.countplot(x=combinedDf['cluster_predicted'], hue=combinedDf['testClass'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
# sns.countplot(x=combinedDf['testCode'],order=combinedDf['testCode'].value_counts().index,hue=combinedDf['cluster_predicted'])
sns.countplot(x=combinedDf['cluster_predicted'], hue=combinedDf['testCode'])
plt.show()

# %%
plt.subplots(figsize = (20,5))
# sns.countplot(x=combinedDf['assessmentItemCode'],order=combinedDf['assessmentItemCode'].value_counts().index,hue=combinedDf['cluster_predicted'])
sns.countplot(x=combinedDf['cluster_predicted'], hue=combinedDf['assessmentItemCode'])
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
# scatter plot
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(for_clustering['userID'],for_clustering['KnowledgeTag'],for_clustering['testCode'],c=for_clustering['answerCode'],alpha=0.5)
ax.set_xlabel('userID')
ax.set_ylabel('KnowledgeTag')
ax.set_zlabel('testCode')
plt.show()

# %%
model = DBSCAN(eps=0.15, min_samples=6)
predict = pd.DataFrame(model.fit_predict(for_clustering))
predict.columns=['predict']

# %%
predict['predict'].unique()
# Out:
# array([-1])

# %% [markdown]
# ## 단변량 분석
#
# ### 데이터 설명
#
# - userID : 사용자의 고유번호입니다. 총 7,442명의 고유 사용자가 있으며, train/test셋은 이 userID를 기준으로 90/10의 비율로 나누어졌습니다.
# - assessmentItemID : 문항의 고유번호입니다. 총 9,454개의 고유 문항이 있습니다. 이 일련 번호에 대한 규칙은 DKT 2강 EDA에서 다루었으니 강의 들어보시면 좋을 것 같습니다.
# - testId : 시험지의 고유번호입니다. 문항과 시험지의 관계는 아래 그림을 참고하여 이해하시면 됩니다. 총 1,537개의 고유한 시험지가 있습니다.
# - answerCode : 사용자가 해당 문항을 맞췄는지 여부에 대한 이진 데이터이며 0은 사용자가 해당 문항을 틀린 것, 1은 사용자가 해당 문항을 맞춘 것입니다.
# - Timestamp : 사용자가 해당문항을 풀기 시작한 시점의 데이터입니다.
# - KnowledgeTag : 문항 당 하나씩 배정되는 태그로, 일종의 중분류 역할을 합니다. 태그 자체의 정보는 비식별화 되어있지만, 문항을 군집화하는데 사용할 수 있습니다. 912개의 고유 태그가 존재합니다.

# %% [markdown]
# ### 결측치
# - train / test의 모든 column에 대해 결측치가 존재하지 않습니다.

# %%
null_check(total, total)
# Out:
# [TOTAL] userID's null : 0
# [TOTAL] assessmentItemID's null : 0
# [TOTAL] testId's null : 0
# [TOTAL] answerCode's null : 0
# [TOTAL] Timestamp's null : 0
# [TOTAL] KnowledgeTag's null : 0

# %% [markdown]
# ### userID
# - train에는 6698, test에는 744명의 유저가 존재합니다.
# - 7442명의 유저를 9:1의 비율로 train / test로 나눈 것 입니다.

# %%
column = 'userID'
nunique(total, total, column)
# Out:
# [TOTAL] userID's number of unique : 7442

# %% [markdown]
# ### assessmentItemID
# - train에 있는 문제들과 test에 있는 문제들이 정확히 같습니다. (개수, 문제번호 모두 동일)
# - 해당 컬럼과 timestamp 컬럼을 이용해 문제별 사용자들의 평균 풀이 시간을 구할 수 있습니다.
# - 해당 컬럼과 timestamp 컬럼을 이용해 유저별 평균 문제 풀이 시간을 구할 수 있습니다.
# - 해당 컬럼을 이용해 문제별 유저들의 정답 비율을 알 수 있습니다.
# - 유저들의 정답 비율은 문제의 난이도를 의미한다고 할 수 있습니다. (정답 비율이 낮으면 난이도가 높은 것이고 문제 풀이시간과 분석을 통해 검증을 해보면 될 것 같습니다.)

# %%
column = 'assessmentItemID'
nunique(total, total, column)
# Out:
# [TOTAL] assessmentItemID's number of unique : 9454

# %% [markdown]
# ### testId
# - 문제가 같기 때문에 문제집 또한 모두 동일한 것으로 추측됩니다.
# - 해당 컬럼과 assessmentItemID 컬럼을 이용해 시험지 별 평균 맞춘 문제 수를 구할 수 있습니다.
# - 시험지 별 평균 맞춘 문제 수는 문제집의 난이도를 의미한다고 추측 가능합니다.

# %%
column = 'testId'
nunique(total, total, column)
# Out:
# [TOTAL] testId's number of unique : 1537

# %% [markdown]
# ### answerCode
# - train에는 맞췄는지 (1) 못맞췄는지 (0)에 대한 값만 존재합니다.
# - 반면 test에는 맞췄는지 (1) 못맞췄는지 (0)와 더불어 각 유저의 마지막으로 푼 문제의 다음 문제를 나타내는 값(-1)이 존재합니다.

# %%
column = 'answerCode'
nunique(total, total, column)
# Out:
# [TOTAL] answerCode's number of unique : 2

# %% [markdown]
# ### Timestamp
# - 각 유저가 각 문제를 풀기 시작한 시간을 나타냅니다.
# - 그렇기에 train / test의 고유값 구성이 다른 것이 당연해 보입니다.
# - Timestamp를 통해 현재 문제를 풀기 시작한 시간과 다음 문제를 시작한 시간을 이용해 한 문제를 푸는데 걸린 시간을 구할 수 있어보입니다.
# - 시계열 관점에서 접근을 한다면 decomposition을 통해 인사이트를 얻을 수 있을 것 같습니다. (decomposition 결과를 피쳐로 사용할 수도 있습니다.)
# - 00~12시 사이에 문제를 많이 풀었고, 13~23시 사이에는 그에 비해 문제를 적게 푼 모습이 보입니다.
# - 새벽 시간 내내 문제 풀이가 많았던 것을 보아 실제 데이터가 아닌 것 같다는 생각도 듭니다.
# - 월별로 봤을 때 차이가 보입니다.

# %%
column = 'Timestamp'
nunique(total, total, column)
# Out:
# [TOTAL] Timestamp's number of unique : 2293142

# %%
hour_train = total[column].apply(lambda x : x.split(' ')[1][:2].strip())
hour_train = hour_train.to_frame()
hour_train = hour_train.sort_values(by=column)

custom_palette_hour_train = {}

for h, cnt in zip(hour_train.value_counts().index, hour_train.value_counts()):
    h = h[0]
    threshold = 100000
    if threshold < cnt:
        custom_palette_hour_train[h] = 'r'
    else:
        custom_palette_hour_train[h] = 'b'

# %%
count_plot(hour_train, hour_train, column, custom_palette_hour_train)
# Out:
# [TOTAL] Timestamp's number of unique : 24

# %%
month_train = total[column].apply(lambda x : x.split(' ')[0][5:7].strip())
month_train = month_train.to_frame()
month_train = month_train.sort_values(by=column)

custom_palette_month_train = {}

for h, cnt in zip(month_train.value_counts().index, month_train.value_counts()):
    h = h[0]
    threshold = 200000
    if threshold < cnt:
        custom_palette_month_train[h] = 'r'
    else:
        custom_palette_month_train[h] = 'b'

# %%
count_plot(month_train, month_train, column, custom_palette_month_train)
# Out:
# [TOTAL] Timestamp's number of unique : 12

# %% [markdown]
# ### KnowledgeTag
# - train / test의 문제가 모두 동일하게 구성되어 있기에 KnowledgeTag도 같은 고유값들을 갖습니다.
# - 대회 데이터 설명에 쓰여있듯이 비슷한 유형의 문제를 찾아내기 위해서 클러스터링을 사용할 수 있습니다.

# %%
column = 'KnowledgeTag'
nunique(total, total, column)
# Out:
# [TOTAL] KnowledgeTag's number of unique : 912

# %% [markdown]
# ## 이변량 분석

# %% [markdown]
# ### userID vs answerCode(target)
# - 시각적으로는 유저별로 정답 여부에 대한 차이가 있어보입니다.
# - 하지만 카이제곱검정을 통해 확인을 했을 때, 카이제곱검정량이 자유도의 2~3배정도의 수치가 나왔기에 관계가 있다고 볼 수 있습니다.

# %%
column, target = "userID", "answerCode"

# 유저별 정답비율
ct1 = pd.crosstab(total[column], total[target], normalize="index")
ct2 = pd.crosstab(total[column], total[target])
# print(ct)
ct1.plot.bar(stacked=True)
plt.gca().axes.xaxis.set_visible(False)
plt.title("Ratio of Answer per User")
plt.show()

# %%
sns.kdeplot(x=1, data=ct2, label="Correct")
sns.kdeplot(x=0, data=ct2, label="Wrong")
plt.legend()
plt.show()

# %%
ct2[1].describe().to_frame()
# Out:
#                  1
# count  7442.000000
# mean    222.196721
# std     228.817305
# min       0.000000
# 25%      45.000000
# 50%     141.000000
# 75%     333.750000
# max    1552.000000

# %%
result = spst.chi2_contingency(ct2)
print("카이제곱통계량", result[0])
print("p-value", result[1])
print("자유도", result[2])
print("기대빈도\n", result[3])
# Out:
# 카이제곱통계량 244772.42072180245
# p-value 0.0
# 자유도 7441
# 기대빈도
#  [[257.29433133 487.70566867]
#  [322.22229683 610.77770317]
#  [ 95.31977913 180.68022087]
#  ...
#  [  5.18042278   9.81957722]
#  [  5.18042278   9.81957722]
#  [  3.10825367   5.89174633]]

# %% [markdown]
# ### user_answerRatio
# - userID를 통해 유저의 정답 비율을 의미하는 user_answerRatio를 만들어 냈습니다.

# %%
ct1_dict = {key : val for key, val in zip(ct1[1].keys(), ct1[1].values)}
total['user_answerRatio'] = total['userID'].map(ct1_dict)

# %%
# 시각화 결과를 보면 두 변수가 어느정도 관계가 있습니다.
a0 = total.loc[total['answerCode']==0]
a1 = total.loc[total['answerCode']==1]
sns.kdeplot(x='user_answerRatio', data=a0, label="Wrong")
sns.kdeplot(x='user_answerRatio', data=a1, label="Correct")
plt.show()

# %%
# user_answerRatio가 증가함에 따라 정답의 비율이 올라갑니다. 이것은 당연한 이야기이죠.
# 하지만 user_answerRatio를 유저의 현재까지의 실력이라고 의미를 부여할 수 있을 것 같습니다.
sns.kdeplot(x='user_answerRatio', data=total, hue='answerCode', multiple='fill')
plt.show()

# %%
# pvalue가 0.05 이하이므로 두 변수가 어느정도 관련이 있습니다.
model = Logit(total['answerCode'], total['user_answerRatio'])
result = model.fit()
print(result.pvalues)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.623956
#          Iterations 5
# user_answerRatio    0.0
# dtype: float64

# %%
tmp = total.groupby('userID')['solvingtime'].mean()
user_solvingtime_dict = {key : val for key, val in zip(tmp.keys(), tmp.values)}
total['user_solvingtime_avg'] = total['userID'].map(user_solvingtime_dict)
total
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  user_answerRatio  assessmentItemCode  testClass  \
# 0                7224          0.630872                   1          6
# 1                7225          0.630872                   2          6
# 2                7225          0.630872                   3          6
# 3                7225          0.630872                   4          6
# 4                7225          0.630872                   5          6
# ...               ...               ...                 ...        ...
# 2525951           438          0.555556                   5          3
# 2525952          8836          0.555556                   1          4
# 2525953          8836          0.555556                   2          4
# 2525954          8836          0.555556                   3          4
# 2525955          8836          0.555556                   4          4
#
#          testCode  solvingtime  trend_solvingtime  seasonal_solvingtime  \
# 0               1            3          11.093614              0.637499
# 1               1            8          13.505966             45.555097
# 2               1            7          15.874614              3.981647
# 3               1            7          18.198388            -17.703348
# 4               1           11          20.476724             23.894059
# ...           ...          ...                ...                   ...
# 2525951        71           60          48.905977             11.094023
# 2525952       165           11          48.905977            -37.905977
# 2525953       165           46          48.905977             -2.905977
# 2525954       165           73          48.905977             24.094023
# 2525955       165           60          48.905977             11.094023
#
#          resid_solvingtime  user_solvingtime_avg
# 0            -8.731113e+00             43.547651
# 1            -5.106106e+01             43.547651
# 2            -1.285626e+01             43.547651
# 3             6.504960e+00             43.547651
# 4            -3.337078e+01             43.547651
# ...                    ...                   ...
# 2525951      -7.105427e-15             52.222222
# 2525952       0.000000e+00             52.222222
# 2525953      -7.105427e-15             52.222222
# 2525954       7.105427e-15             52.222222
# 2525955       0.000000e+00             52.222222
#
# [2525956 rows x 15 columns]

# %%
# 유저별 정답 누적합
tmp = total.groupby('userID')['answerCode'].cumsum()
total['user_answer_cumsum_prev'] = tmp.values
total['user_answer_cumsum_prev'] = total['user_answer_cumsum_prev'].fillna(0.0)
user_length = total.groupby(by=["userID"])["assessmentItemID"].agg(len).values
start = 0
for length in np.cumsum(user_length):
    total.iloc[start:length, 15] = total.iloc[start:length, 15].shift(1)
    start = length
total['user_answer_cumsum_prev'] = total['user_answer_cumsum_prev'].fillna(0.0)
total
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  user_answerRatio  assessmentItemCode  testClass  \
# 0                7224          0.630872                   1          6
# 1                7225          0.630872                   2          6
# 2                7225          0.630872                   3          6
# 3                7225          0.630872                   4          6
# 4                7225          0.630872                   5          6
# ...               ...               ...                 ...        ...
# 2525951           438          0.555556                   5          3
# 2525952          8836          0.555556                   1          4
# 2525953          8836          0.555556                   2          4
# 2525954          8836          0.555556                   3          4
# 2525955          8836          0.555556                   4          4
#
#          testCode  solvingtime  trend_solvingtime  seasonal_solvingtime  \
# 0               1            3          11.093614              0.637499
# 1               1            8          13.505966             45.555097
# 2               1            7          15.874614              3.981647
# 3               1            7          18.198388            -17.703348
# 4               1           11          20.476724             23.894059
# ...           ...          ...                ...                   ...
# 2525951        71           60          48.905977             11.094023
# 2525952       165           11          48.905977            -37.905977
# 2525953       165           46          48.905977             -2.905977
# 2525954       165           73          48.905977             24.094023
# 2525955       165           60          48.905977             11.094023
#
#          resid_solvingtime  user_solvingtime_avg  user_answer_cumsum_prev  \
# 0            -8.731113e+00             43.547651                      0.0
# 1            -5.106106e+01             43.547651                      1.0
# 2            -1.285626e+01             43.547651                      2.0
# 3             6.504960e+00             43.547651                      3.0
# 4            -3.337078e+01             43.547651                      4.0
# ...                    ...                   ...                      ...
# 2525951      -7.105427e-15             52.222222                      1.0
# 2525952       0.000000e+00             52.222222                      1.0
# 2525953      -7.105427e-15             52.222222                      2.0
# 2525954       7.105427e-15             52.222222                      3.0
# 2525955       0.000000e+00             52.222222                      4.0
#
#          user_answer_cumcount_prev  user_answerRatio_cum_prev
# 0                                0                   0.000000
# 1                                1                   1.000000
# 2                                2                   1.000000
# 3                                3                   1.000000
# 4                                4                   1.000000
# ...                            ...                        ...
# 2525951                          4                   0.250000
# 2525952                          5                   0.200000
# 2525953                          6                   0.333333
# 2525954                          7                   0.428571
# 2525955                          8                   0.500000
#
# [2525956 rows x 18 columns]

# %%
model = CatBoostClassifier()
start, end = 0, 10
for i in range(len(train_data)):
    train_data.iloc[start:end, :]
    answer = train_data.iloc[end+1, ansewrCode]
    model.fit(train_data, answer)
    start = end
    end += 10

# %%
total.iloc[740:750, [0, -1]]
# Out:
#      userID  user_answerRatio_cum_prev
# 740       0                   0.632432
# 741       0                   0.632928
# 742       0                   0.632075
# 743       0                   0.632571
# 744       0                   0.631720
# 745       1                        inf
# 746       1                   1.000000
# 747       1                   1.000000
# 748       1                   1.000000
# 749       1                   1.000000

# %%
# 유저별 문제 수 누적합
# 유저별 특정시점까지의 정답비율 (미래 데이터 포함 x)
tmp = total.groupby('userID')['answerCode'].cumcount()
total['user_answer_cumcount_prev'] = tmp.values
total['user_answerRatio_cum_prev'] = total['user_answer_cumsum_prev'] / total['user_answer_cumcount_prev']
total['user_answerRatio_cum_prev'] = total['user_answerRatio_cum_prev'].fillna(0.0)
total
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  user_answerRatio  assessmentItemCode  testClass  \
# 0                7224          0.630872                   1          6
# 1                7225          0.630872                   2          6
# 2                7225          0.630872                   3          6
# 3                7225          0.630872                   4          6
# 4                7225          0.630872                   5          6
# ...               ...               ...                 ...        ...
# 2525951           438          0.555556                   5          3
# 2525952          8836          0.555556                   1          4
# 2525953          8836          0.555556                   2          4
# 2525954          8836          0.555556                   3          4
# 2525955          8836          0.555556                   4          4
#
#          testCode  solvingtime  trend_solvingtime  seasonal_solvingtime  \
# 0               1            3          11.093614              0.637499
# 1               1            8          13.505966             45.555097
# 2               1            7          15.874614              3.981647
# 3               1            7          18.198388            -17.703348
# 4               1           11          20.476724             23.894059
# ...           ...          ...                ...                   ...
# 2525951        71           60          48.905977             11.094023
# 2525952       165           11          48.905977            -37.905977
# 2525953       165           46          48.905977             -2.905977
# 2525954       165           73          48.905977             24.094023
# 2525955       165           60          48.905977             11.094023
#
#          resid_solvingtime  user_solvingtime_avg  user_answer_cumsum_prev  \
# 0            -8.731113e+00             43.547651                      0.0
# 1            -5.106106e+01             43.547651                      1.0
# 2            -1.285626e+01             43.547651                      2.0
# 3             6.504960e+00             43.547651                      3.0
# 4            -3.337078e+01             43.547651                      4.0
# ...                    ...                   ...                      ...
# 2525951      -7.105427e-15             52.222222                      1.0
# 2525952       0.000000e+00             52.222222                      1.0
# 2525953      -7.105427e-15             52.222222                      2.0
# 2525954       7.105427e-15             52.222222                      3.0
# 2525955       0.000000e+00             52.222222                      4.0
#
#          user_answer_cumcount_prev  user_answerRatio_cum_prev
# 0                                0                   0.000000
# 1                                1                   1.000000
# 2                                2                   1.000000
# 3                                3                   1.000000
# 4                                4                   1.000000
# ...                            ...                        ...
# 2525951                          4                   0.250000
# 2525952                          5                   0.200000
# 2525953                          6                   0.333333
# 2525954                          7                   0.428571
# 2525955                          8                   0.500000
#
# [2525956 rows x 18 columns]

# %%
total.iloc[2525951-10: 2525951]
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2525941    7440       A030136005  A030000136           0  2020-09-23 09:21:53
# 2525942    7440       A030197001  A030000197           1  2020-10-21 08:31:45
# 2525943    7440       A030197002  A030000197           0  2020-10-21 08:32:46
# 2525944    7440       A030197003  A030000197           0  2020-10-21 08:33:15
# 2525945    7440       A030197004  A030000197           0  2020-10-21 08:33:17
# 2525946    7440       A030197005  A030000197           0  2020-10-21 08:33:20
# 2525947    7441       A030071001  A030000071           0  2020-06-05 06:46:41
# 2525948    7441       A030071002  A030000071           0  2020-06-05 06:48:43
# 2525949    7441       A030071003  A030000071           1  2020-06-05 06:49:23
# 2525950    7441       A030071004  A030000071           0  2020-06-05 06:49:57
#
#          KnowledgeTag  user_answerRatio  assessmentItemCode  testClass  \
# 2525941          7691          0.400000                   5          3
# 2525942          1984          0.400000                   1          3
# 2525943          1984          0.400000                   2          3
# 2525944          1984          0.400000                   3          3
# 2525945          1984          0.400000                   4          3
# 2525946          1984          0.400000                   5          3
# 2525947           438          0.555556                   1          3
# 2525948           438          0.555556                   2          3
# 2525949           438          0.555556                   3          3
# 2525950           438          0.555556                   4          3
#
#          testCode  solvingtime  trend_solvingtime  seasonal_solvingtime  \
# 2525941       136           60          33.807518             26.192482
# 2525942       197           61          33.807518             27.192482
# 2525943       197           29          33.807518             -4.807518
# 2525944       197            2          33.807518            -31.807518
# 2525945       197            3          33.807518            -30.807518
# 2525946       197           60          33.807518             26.192482
# 2525947        71          122          48.905977             73.094023
# 2525948        71           40          48.905977             -8.905977
# 2525949        71           34          48.905977            -14.905977
# 2525950        71           24          48.905977            -24.905977
#
#          resid_solvingtime  user_solvingtime_avg  user_answer_cumsum_prev  \
# 2525941       0.000000e+00             33.733333                      5.0
# 2525942       7.105427e-15             33.733333                      5.0
# 2525943       0.000000e+00             33.733333                      6.0
# 2525944       0.000000e+00             33.733333                      6.0
# 2525945       0.000000e+00             33.733333                      6.0
# 2525946       7.105427e-15             33.733333                      6.0
# 2525947      -2.131628e-14             52.222222                      0.0
# 2525948      -7.105427e-15             52.222222                      0.0
# 2525949      -7.105427e-15             52.222222                      0.0
# 2525950      -2.842171e-14             52.222222                      1.0
#
#          user_answer_cumcount_prev  user_answerRatio_cum_prev
# 2525941                          9                   0.555556
# 2525942                         10                   0.500000
# 2525943                         11                   0.545455
# 2525944                         12                   0.500000
# 2525945                         13                   0.461538
# 2525946                         14                   0.428571
# 2525947                          0                   0.000000
# 2525948                          1                   0.000000
# 2525949                          2                   0.000000
# 2525950                          3                   0.333333

# %%
# 유저별 문제번호별 정답률
tmp = total.groupby(['userID', 'assessmentItemCode'])['answerCode']
tmp.mean()
# total['user_assessmentItemCode_answerRatio'] =
# Out:
# userID  assessmentItemCode
# 0       1                     0.817308
#         2                     0.769231
#         3                     0.653846
#         4                     0.692308
#         5                     0.553398
#                                 ...
# 7441    1                     0.500000
#         2                     0.500000
#         3                     1.000000
#         4                     0.500000
#         5                     0.000000
# Name: answerCode, Length: 67036, dtype: float64

# %% [markdown]
# ### assessmentItemID vs answerCode
# -

# %%
column, target = "assessmentItemID", "answerCode"

# 문제별 정답비율
ct1 = pd.crosstab(total[column], total[target], normalize="index")
ct2 = pd.crosstab(total[column], total[target])
# print(ct)

ct1.plot.bar(stacked=True)
plt.gca().axes.xaxis.set_visible(False)
plt.show()

# %%
result = spst.chi2_contingency(ct2)
print("카이제곱통계량", result[0])
print("p-value", result[1])
print("자유도", result[2])
print("기대빈도\n", result[3])
# Out:
# 카이제곱통계량 388071.41183004796
# p-value 0.0
# 자유도 9453
# 기대빈도
#  [[109.56203603 207.43796397]
#  [109.56203603 207.43796397]
#  [109.56203603 207.43796397]
#  ...
#  [ 15.55297041  29.44702959]
#  [ 15.55297041  29.44702959]
#  [ 15.55297041  29.44702959]]

# %% [markdown]
# #### assessmentItemCode
# - assessmentItemID를 통해 assessmentItemCode를 만들었습니다.
# - 해당 피쳐와 answerCode간의 plot을 보았을 때, 1~13순으로 난이도라고 예상할 수 있을 것 같습니다.
# - 앞쪽에는 쉬운 문제이기에 정답비율이 높고 뒤쪽에는 어려운 문제이기에 정답비율이 낮다는 가정입니다.

# %%
total = extract_assessmentItemID(total)
ct3 = pd.crosstab(total['assessmentItemCode'], total[target], normalize="index")
ct4 = pd.crosstab(total['assessmentItemCode'], total[target])
ct3.plot.bar(stacked=True)
# plt.gca().axes.xaxis.set_visible(False)
plt.show()

# %%
result = spst.chi2_contingency(ct4)
print("카이제곱통계량", result[0])
print("p-value", result[1])
print("자유도", result[2])
print("기대빈도\n", result[3])
# Out:
# 카이제곱통계량 71540.46532889291
# p-value 0.0
# 자유도 12
# 기대빈도
#  [[1.43100200e+05 2.71248800e+05]
#  [1.42805606e+05 2.70690394e+05]
#  [1.43063937e+05 2.71180063e+05]
#  [1.42295162e+05 2.69722838e+05]
#  [1.38706511e+05 2.62920489e+05]
#  [7.61183694e+04 1.44283631e+05]
#  [4.89950572e+04 9.28709428e+04]
#  [2.57556806e+04 4.88203194e+04]
#  [7.11168439e+03 1.34803156e+04]
#  [2.05144742e+03 3.88855258e+03]
#  [1.29441497e+03 2.45358503e+03]
#  [9.66666890e+02 1.83233311e+03]
#  [1.03263094e+02 1.95736906e+02]]

# %%
kde_hist_plot(total, 'assessmentItemCode')

# %% [markdown]
# ### testId vs answerCode
# - testId를 그대로 봤을 때도 testId별 정답 비율 차이가 조금은 있어보입니다.

# %%
column, target = "testId", "answerCode"

# 문제집별 정답비율
ct1 = pd.crosstab(total[column], total[target], normalize="index")
ct2 = pd.crosstab(total[column], total[target])
# print(ct)

ct1.plot.bar(stacked=True)
plt.gca().axes.xaxis.set_visible(False)
plt.show()

# %%
result = spst.chi2_contingency(ct2)
print("카이제곱통계량", result[0])
print("p-value", result[1])
print("자유도", result[2])
print("기대빈도\n", result[3])
# Out:
# 카이제곱통계량 231537.77960189848
# p-value 0.0
# 자유도 1536
# 기대빈도
#  [[ 604.3826575  1145.6173425 ]
#  [ 604.3826575  1145.6173425 ]
#  [ 604.3826575  1145.6173425 ]
#  ...
#  [ 103.60845557  196.39154443]
#  [ 103.60845557  196.39154443]
#  [ 102.2270095   193.7729905 ]]

# %% [markdown]
# #### testClass & testCode
# - testId를 통해 시험지 분류를 위한 testClass를 만들었습니다.
# - testId를 통해 testCode를 만들었습니다.
# - testClass와 answerCode의 관계를 시각화를 통해 보았을 때, 근소한 차이지만 7~9보다 1~6의 정답 비율이 더 높았습니다.

# %%
total = extract_testId(total)
ct3 = pd.crosstab(total['testClass'], total[target], normalize="index")
ct4 = pd.crosstab(total['testClass'], total[target])

ct3.plot.bar(stacked=True)
plt.show()

# %%
result = spst.chi2_contingency(ct4)
print("카이제곱통계량", result[0])
print("p-value", result[1])
print("자유도", result[2])
print("기대빈도\n", result[3])
# Out:
# 카이제곱통계량 122814.12465605553
# p-value 0.0
# 자유도 8
# 기대빈도
#  [[104877.65915162 198797.34084838]
#  [102663.20109456 194599.79890544]
#  [104770.59708087 198594.40291913]
#  [103747.63626286 196655.36373714]
#  [105790.10428369 200526.89571631]
#  [102325.09216788 193958.90783212]
#  [108850.00733821 206326.99266179]
#  [ 93883.42056948 177957.57943052]
#  [ 45460.28205084  86170.71794916]]

# %%
kde_hist_plot(total, 'testClass')

# %%
ct5 = pd.crosstab(total['testCode'], total[target], normalize="index")
ct6 = pd.crosstab(total['testCode'], total[target])

ct5.plot.bar(stacked=True)
plt.gca().axes.xaxis.set_visible(False)
plt.show()

# %%
result = spst.chi2_contingency(ct6)
print("카이제곱통계량", result[0])
print("p-value", result[1])
print("자유도", result[2])
print("기대빈도\n", result[3])
# Out:
# 카이제곱통계량 37059.073138634645
# p-value 0.0
# 자유도 197
# 기대빈도
#  [[ 5784.80543604 10965.19456396]
#  [ 4800.52510812  9099.47489188]
#  [ 6527.33270097 12372.66729903]
#  [ 4731.4528044   8968.5471956 ]
#  [ 6285.57963797 11914.42036203]
#  [ 4662.38050069  8837.61949931]
#  [ 6492.45118759 12306.54881241]
#  [ 4904.13356369  9295.86643631]
#  [ 6751.81768804 12798.18231196]
#  [ 4800.52510812  9099.47489188]
#  [ 6561.86885282 12438.13114718]
#  [ 4541.50396919  8608.49603081]
#  [ 6371.92001761 12078.07998239]
#  [ 5335.8354619  10114.1645381 ]
#  [ 6337.38386575 12012.61613425]
#  [ 5957.48619533 11292.51380467]
#  [ 6907.23037139 13092.76962861]
#  [ 6423.72424539 12176.27575461]
#  [ 6233.77541018 11816.22458982]
#  [ 5283.6858726  10015.3141274 ]
#  [ 5715.38777081 10833.61222919]
#  [ 5473.98006933 10376.01993067]
#  [ 5957.14083381 11291.85916619]
#  [ 5421.83048002 10277.16951998]
#  [ 6181.9711824  11718.0288176 ]
#  [ 5422.17584154 10277.82415846]
#  [ 5733.00120826 10866.99879174]
#  [ 5318.56738597 10081.43261403]
#  [ 5733.00120826 10866.99879174]
#  [ 5266.76315819  9983.23684181]
#  [ 5507.82549815 10440.17450185]
#  [ 5663.92890454 10736.07109546]
#  [ 6078.36272683 11521.63727317]
#  [ 5819.3415879  11030.6584121 ]
#  [ 5076.81432297  9623.18567703]
#  [ 5249.14972074  9949.85027926]
#  [ 4990.47394333  9459.52605667]
#  [ 4679.64857662  8870.35142338]
#  [ 5197.69085447  9852.30914553]
#  [ 4645.11242476  8804.88757524]
#  [ 4506.96781733  8543.03218267]
#  [ 4403.01400024  8345.98599976]
#  [ 5576.89780186 10571.10219814]
#  [ 5715.38777081 10833.61222919]
#  [ 5784.80543604 10965.19456396]
#  [ 4955.59242996  9393.40757004]
#  [ 5992.02234718 11357.97765282]
#  [ 5059.54624704  9590.45375296]
#  [ 5784.46007452 10964.53992548]
#  [ 4852.3293359   9197.6706641 ]
#  [ 5663.92890454 10736.07109546]
#  [ 5249.14972074  9949.85027926]
#  [ 5127.92782772  9720.07217228]
#  [ 4524.23589326  8575.76410674]
#  [ 5767.53736011 10932.46263989]
#  [ 5059.54624704  9590.45375296]
#  [ 6285.57963797 11914.42036203]
#  [ 5232.22700633  9917.77299367]
#  [ 5353.10353783 10146.89646217]
#  [ 4748.72088033  9001.27911967]
#  [ 5439.09855595 10309.90144405]
#  [ 4869.25205031  9229.74794969]
#  [ 5300.95394852 10048.04605148]
#  [ 3988.58017796  7560.41982204]
#  [ 5197.69085447  9852.30914553]
#  [ 4316.6736206   8182.3263794 ]
#  [ 5490.90278374 10408.09721626]
#  [ 4714.18472848  8935.81527152]
#  [ 5196.65476992  9850.34523008]
#  [ 4541.15860767  8607.84139233]
#  [ 5266.41779667  9982.58220333]
#  [ 4265.21475433  8084.78524567]
#  [ 5300.60858701 10047.39141299]
#  [ 4315.63753605  8180.36246395]
#  [ 4920.71091658  9327.28908342]
#  [ 3936.43058866  7461.56941134]
#  [ 5094.0823989   9655.9176011 ]
#  [ 4265.21475433  8084.78524567]
#  [ 5353.10353783 10146.89646217]
#  [ 4281.79210723  8116.20789277]
#  [ 4800.52510812  9099.47489188]
#  [ 4092.53399505  7757.46600495]
#  [ 5076.46896145  9622.53103855]
#  [ 4023.11632982  7625.88367018]
#  [ 4817.79318405  9132.20681595]
#  [ 4713.83936696  8935.16063304]
#  [ 5370.02625224 10178.97374776]
#  [ 4402.66863873  8345.33136127]
#  [ 4990.47394333  9459.52605667]
#  [ 4679.64857662  8870.35142338]
#  [ 5283.34051108 10014.65948892]
#  [ 4317.01898212  8182.98101788]
#  [ 4627.49898731  8771.50101269]
#  [ 4334.28705805  8215.71294195]
#  [ 4731.4528044   8968.5471956 ]
#  [ 4109.80207098  7790.19792902]
#  [ 4989.78322029  9458.21677971]
#  [ 4109.11134794  7788.88865206]
#  [ 5301.29931004 10048.70068996]
#  [ 4212.37444199  7984.62555801]
#  [ 5265.38171211  9980.61828789]
#  [ 4143.99286132  7855.00713868]
#  [ 5369.3355292  10177.6644708 ]
#  [ 4403.01400024  8345.98599976]
#  [ 5386.94896665 10211.05103335]
#  [ 4317.01898212  8182.98101788]
#  [ 5489.86669918 10406.13330082]
#  [ 4403.01400024  8345.98599976]
#  [ 5404.21704258 10243.78295742]
#  [ 4213.06516503  7985.93483497]
#  [ 5179.73205551  9818.26794449]
#  [ 4160.57021421  7886.42978579]
#  [ 5023.62864911  9522.37135089]
#  [ 4212.37444199  7984.62555801]
#  [ 5075.77823842  9621.22176158]
#  [ 3918.81715121  7428.18284879]
#  [ 4989.09249726  9456.90750274]
#  [ 4021.38952222  7622.61047778]
#  [ 4817.10246101  9130.89753899]
#  [ 3900.16762921  7392.83237079]
#  [ 4817.44782253  9131.55217747]
#  [ 4539.43180008  8604.56819992]
#  [ 5075.77823842  9621.22176158]
#  [ 5071.97926171  9614.02073829]
#  [ 4987.02032815  9452.97967185]
#  [ 5074.74215386  9619.25784614]
#  [ 5575.51635579 10568.48364421]
#  [ 5593.47515475 10602.52484525]
#  [ 4885.48404169  9260.51595831]
#  [ 4952.13881477  9386.86118523]
#  [ 5433.57277166 10299.42722834]
#  [ 3813.82724956  7229.17275044]
#  [ 5004.63376559  9486.36623441]
#  [ 4158.84340662  7883.15659338]
#  [ 5156.59283376  9774.40716624]
#  [ 4642.69489413  8800.30510587]
#  [ 5055.0565473   9581.9434527 ]
#  [ 4448.94708221  8433.05291779]
#  [ 4159.53412965  7884.46587035]
#  [ 3656.68775861  6931.31224139]
#  [ 4331.5241659   8210.4758341 ]
#  [ 3346.20775342  6342.79224658]
#  [ 4399.90574658  8340.09425342]
#  [ 3260.55809682  6180.44190318]
#  [ 3968.54920988  7522.45079012]
#  [ 3258.14056619  6175.85943381]
#  [ 3777.2189286   7159.7810714 ]
#  [ 3173.87235565  6016.12764435]
#  [ 4054.19886649  7684.80113351]
#  [ 3208.06314599  6080.93685401]
#  [ 4176.11148254  7915.88851746]
#  [ 3744.06422281  7096.93577719]
#  [ 4274.19415382  8101.80584618]
#  [ 3519.23387422  6670.76612578]
#  [ 3914.67281299  7420.32718701]
#  [ 3605.22889235  6833.77110765]
#  [ 4293.53439886  8138.46560114]
#  [ 3296.13033323  6247.86966677]
#  [ 4106.34845579  7783.65154421]
#  [ 2778.08805537  5265.91194463]
#  [ 4381.60158609  8305.39841391]
#  [ 3122.06812787  5917.93187213]
#  [ 3857.68816242  7312.31183758]
#  [ 2830.5830062   5365.4169938 ]
#  [ 2898.27386384  5493.72613616]
#  [ 2140.20533058  4056.79466942]
#  [ 2881.69651094  5462.30348906]
#  [ 2310.81392075  4380.18607925]
#  [ 2776.7066093   5263.2933907 ]
#  [ 2863.39235046  5427.60764954]
#  [ 2657.90224691  5038.09775309]
#  [ 2761.51070248  5234.48929752]
#  [ 2518.72155493  4774.27844507]
#  [ 2675.51568436  5071.48431564]
#  [ 2639.94344795  5004.05655205]
#  [ 1656.69920458  3140.30079542]
#  [ 2589.17530472  4907.82469528]
#  [ 1466.75036937  2780.24963063]
#  [ 2467.26268866  4676.73731134]
#  [ 1450.51837799  2749.48162201]
#  [ 2673.09815373  5066.90184627]
#  [ 2260.04577752  4283.95422248]
#  [ 2519.75763948  4776.24236052]
#  [ 3228.43947559  6119.56052441]
#  [ 2535.98963086  4807.01036914]
#  [ 2346.38615716  4447.61384284]
#  [ 2415.45846088  4578.54153912]
#  [ 2053.86495093  3893.13504907]
#  [ 1639.43112865  3107.56887135]
#  [ 2572.25259031  4875.74740969]
#  [ 1983.41120115  3759.58879885]
#  [ 2448.61316666  4641.38683334]
#  [ 2312.19536682  4382.80463318]
#  [  966.66689048  1832.33310952]
#  [ 1673.62191899  3172.37808101]
#  [  500.42884041   948.57115959]
#  [ 1137.96620369  2157.03379631]
#  [  361.59350994   685.40649006]]

# %%
kde_hist_plot(total, 'testCode')

# %%
for i in range(1, 10):
    print(f"testClass {i}'s length : {len(total.loc[total['testClass']==i])}")
# Out:
# testClass 1's length : 303675
# testClass 2's length : 297263
# testClass 3's length : 303365
# testClass 4's length : 300403
# testClass 5's length : 306317
# testClass 6's length : 296284
# testClass 7's length : 315177
# testClass 8's length : 271841
# testClass 9's length : 131631

# %% [markdown]
# ### Timestamp vs answerCode
# - 문제 풀이시간 컬럼을 만들어서 decomposition을 수행했습니다.
# - decomposition 결과 값들과 answerCode의 관계를 시각화 했을 때, 풀이시간에 따른 차이가 있어보입니다.

# %%
total
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2525951    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2525952    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2525953    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2525954    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2525955    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  user_answerRatio  assessmentItemCode  testClass  \
# 0                7224          0.630872                   1          6
# 1                7225          0.630872                   2          6
# 2                7225          0.630872                   3          6
# 3                7225          0.630872                   4          6
# 4                7225          0.630872                   5          6
# ...               ...               ...                 ...        ...
# 2525951           438          0.555556                   5          3
# 2525952          8836          0.555556                   1          4
# 2525953          8836          0.555556                   2          4
# 2525954          8836          0.555556                   3          4
# 2525955          8836          0.555556                   4          4
#
#          testCode
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 2525951        71
# 2525952       165
# 2525953       165
# 2525954       165
# 2525955       165
#
# [2525956 rows x 10 columns]

# %%
total['solvingtime'] = 0
solvingtime = np.array([0 for _ in range(len(total))])
trend = np.array([0 for _ in range(len(total))], dtype=float)
seasonal = np.array([0 for _ in range(len(total))], dtype=float)
resid = np.array([0 for _ in range(len(total))], dtype=float)

total_decompose_col = {'trend_solvingtime' : trend,
                       'seasonal_solvingtime' : seasonal,
                       'resid_solvingtime' : resid}

for userid in tqdm(total['userID'].unique()):
    dummy = total.loc[total['userID']==userid].copy()
    dummy['endtime'] = dummy['Timestamp'].shift(-1)
    grouped = dummy.groupby(by=['testId'])
    for key, group in grouped:
        indices = group.index
        group.iloc[-1, -1] = pd.to_datetime(group.iloc[-2, -1]) + datetime.timedelta(seconds=60)
        group['solvingtime'] = pd.to_datetime(group['endtime']) - pd.to_datetime(group['Timestamp'])
        solvingtime[indices] = group['solvingtime'].apply(lambda x : x.seconds if x.seconds < 2000 else 60)
        dummy['solvingtime'][indices] = group['solvingtime'].apply(lambda x : x.seconds if x.seconds < 2000 else 60)
    
    res = STL(dummy.set_index(dummy['Timestamp'])['solvingtime'], period=3600).fit()
    dummy_indices = dummy.index
    total_decompose_col['trend_solvingtime'][dummy_indices] = res.trend.values
    total_decompose_col['seasonal_solvingtime'][dummy_indices] = res.seasonal.values
    total_decompose_col['resid_solvingtime'][dummy_indices] = res.resid.values

total['solvingtime'] = solvingtime
total = pd.concat([total, pd.DataFrame(total_decompose_col)], axis=1)
# Out:
# 100%|██████████| 7442/7442 [19:52<00:00,  6.24it/s]

# %%
kde_hist_plot(total, 'trend_solvingtime')

# %%
kde_hist_plot(total, 'seasonal_solvingtime')

# %%
kde_hist_plot(total, 'resid_solvingtime')

# %% [markdown]
# ### KnowledgeTag vs answerCode
# -

# %%
total['KnowledgeTag'].value_counts()
# Out:
# 7597    14350
# 7600    11900
# 2010    11198
# 7621    10850
# 8127     9896
#         ...
# 2613       50
# 7125       50
# 4978       50
# 2871       50
# 5142       50
# Name: KnowledgeTag, Length: 912, dtype: int64

# %%
test_df
# Out:
#         userID assessmentItemID  ...            Timestamp  KnowledgeTag
# 0            3       A050023001  ...  2020-01-09 10:56:31          2626
# 1            3       A050023002  ...  2020-01-09 10:56:57          2626
# 2            3       A050023003  ...  2020-01-09 10:58:31          2625
# 3            3       A050023004  ...  2020-01-09 10:58:36          2625
# 4            3       A050023006  ...  2020-01-09 10:58:43          2623
# ...        ...              ...  ...                  ...           ...
# 260109    7439       A040130001  ...  2020-10-14 23:07:23          8832
# 260110    7439       A040130002  ...  2020-10-14 23:07:41          8832
# 260111    7439       A040130003  ...  2020-10-14 23:08:02          8244
# 260112    7439       A040130004  ...  2020-10-14 23:09:31          8244
# 260113    7439       A040130005  ...  2020-10-14 23:10:03          8832
#
# [260114 rows x 6 columns]

# %%
# 유저별 문제집별 맞춘 문제수, 해당 문제집 문제수 확인
user_test_answer_ratio = test_df.groupby(by=["userID", "testId"], as_index=False)["assessmentItemID", "answerCode"].agg({"assessmentItemID" : pd.value_counts, "answerCode" : sum})
user_test_answer_ratio['assessmentItemID_cnt'] = user_test_answer_ratio['assessmentItemID'].apply(lambda x: len(x))
user_test_answer_ratio['answer_ratio_per_test'] = user_test_answer_ratio['answerCode'] / user_test_answer_ratio['assessmentItemID_cnt']
user_test_answer_ratio
# Out:
# /tmp/ipykernel_9270/2779260142.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   user_test_answer_ratio = test_df.groupby(by=["userID", "testId"], as_index=False)["assessmentItemID", "answerCode"].agg({"assessmentItemID" : pd.value_counts, "answerCode" : sum})
#        userID      testId  ... assessmentItemID_cnt  answer_ratio_per_test
# 0           3  A020000001  ...                    5               0.800000
# 1           3  A020000005  ...                    5               1.000000
# 2           3  A020000007  ...                    5               1.000000
# 3           3  A020000011  ...                    5               1.000000
# 4           3  A020000013  ...                    5               1.000000
# ...       ...         ...  ...                  ...                    ...
# 42020    7417  A010000107  ...                    6               0.000000
# 42021    7417  A050000193  ...                    4               0.250000
# 42022    7439  A040000003  ...                    5               0.800000
# 42023    7439  A040000130  ...                    5               0.400000
# 42024    7439  A040000197  ...                    6               0.666667
#
# [42025 rows x 6 columns]

# %%
# 문제집 별 유저들의 평균 정답률
user_test_answer_ratio.groupby(by=["testId"])["answer_ratio_per_test"].mean().to_frame()
# Out:
#             answer_ratio_per_test
# testId
# A010000001               0.925000
# A010000002               0.953846
# A010000003               0.830769
# A010000004               0.882927
# A010000005               0.813333
# ...                           ...
# A090000070               0.696429
# A090000071               0.425000
# A090000072               0.766667
# A090000073               0.600000
# A090000074               0.366667
#
# [1537 rows x 1 columns]

# %%
for_test = pd.concat([train_df, test_df], axis=0)
for_test = for_test.sort_values(by=["userID", "Timestamp",]).reset_index(drop=True)
for_test = extract_assessmentItemID(for_test)
for_test = extract_testId(for_test)

for_test['solvingtime'] = 0
solvingtime = np.array([0 for _ in range(len(for_test))])
trend = np.array([0 for _ in range(len(for_test))], dtype=float)
seasonal = np.array([0 for _ in range(len(for_test))], dtype=float)
resid = np.array([0 for _ in range(len(for_test))], dtype=float)

for_test_decompose_col = {'trend_solvingtime' : trend,
                       'seasonal_solvingtime' : seasonal,
                       'resid_solvingtime' : resid}

for userid in tqdm(for_test['userID'].unique()):
    dummy = for_test.loc[for_test['userID']==userid].copy()
    dummy['endtime'] = dummy['Timestamp'].shift(-1)
    grouped = dummy.groupby(by=['testId'])
    for key, group in grouped:
        indices = group.index
        group.iloc[-1, -1] = pd.to_datetime(group.iloc[-2, -1]) + datetime.timedelta(seconds=60)
        group['solvingtime'] = pd.to_datetime(group['endtime']) - pd.to_datetime(group['Timestamp'])
        solvingtime[indices] = group['solvingtime'].apply(lambda x : x.seconds if x.seconds < 2000 else 60)
        dummy['solvingtime'][indices] = group['solvingtime'].apply(lambda x : x.seconds if x.seconds < 2000 else 60)

    res = STL(dummy.set_index(dummy['Timestamp'])['solvingtime'], period=60).fit()
    dummy_indices = dummy.index
    for_test_decompose_col['trend_solvingtime'][dummy_indices] = res.trend.values
    for_test_decompose_col['seasonal_solvingtime'][dummy_indices] = res.seasonal.values
    for_test_decompose_col['resid_solvingtime'][dummy_indices] = res.resid.values

for_test['solvingtime'] = solvingtime
for_test = pd.concat([for_test, pd.DataFrame(for_test_decompose_col)], axis=1)
for_test
# Out:
# 100%|██████████| 7442/7442 [22:29<00:00,  5.52it/s]
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2526695    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2526698    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2526699    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  assessmentItemCode  testClass  testCode  solvingtime  \
# 0                7224                   1          6         1            3
# 1                7225                   2          6         1            8
# 2                7225                   3          6         1            7
# 3                7225                   4          6         1            7
# 4                7225                   5          6         1           11
# ...               ...                 ...        ...       ...          ...
# 2526695           438                   5          3        71           60
# 2526696          8836                   1          4       165           11
# 2526697          8836                   2          4       165           46
# 2526698          8836                   3          4       165           73
# 2526699          8836                   4          4       165           60
#
#          trend_solvingtime  seasonal_solvingtime  resid_solvingtime
# 0                53.914628            -54.685377       3.770749e+00
# 1                54.018292            -47.133404       1.115112e+00
# 2                54.122052            -30.645419      -1.647663e+01
# 3                54.225885            -42.518931      -4.706954e+00
# 4                54.329777            -57.067813       1.373804e+01
# ...                    ...                   ...                ...
# 2526695          29.708316             30.291684       1.065814e-14
# 2526696          29.708316            -18.708316       0.000000e+00
# 2526697          29.708316             16.291684       7.105427e-15
# 2526698          29.708316             43.291684       0.000000e+00
# 2526699          29.708316             30.291684       7.105427e-15
#
# [2526700 rows x 13 columns]

# %% [markdown]
# ### train / test split
# -

# %%
tmp = for_test.groupby('userID')['solvingtime'].mean()
user_solvingtime_dict = {key : val for key, val in zip(tmp.keys(), tmp.values)}
for_test['user_solvingtime_avg'] = for_test['userID'].map(user_solvingtime_dict)

# 유저별 정답 누적합
tmp = for_test.groupby('userID')['answerCode'].cumsum()
for_test['user_answer_cumsum_prev'] = tmp.values
for_test['user_answer_cumsum_prev'] = for_test['user_answer_cumsum_prev'].fillna(0.0)
user_length = for_test.groupby(by=["userID"])["assessmentItemID"].agg(len).values
start = 0
for length in tqdm(np.cumsum(user_length)):
    for_test.iloc[start:length, 14] = for_test.iloc[start:length, 14].shift(1)
    start = length
for_test['user_answer_cumsum_prev'] = for_test['user_answer_cumsum_prev'].fillna(0.0)

# 유저별 문제 수 누적합
# 유저별 특정시점까지의 정답비율 (미래 데이터 포함 x)
tmp = for_test.groupby('userID')['answerCode'].cumcount()
for_test['user_answer_cumcount_prev'] = tmp.values
for_test['user_answerRatio_cum_prev'] = for_test['user_answer_cumsum_prev'] / for_test['user_answer_cumcount_prev']
for_test['user_answerRatio_cum_prev'] = for_test['user_answerRatio_cum_prev'].fillna(0.0)
for_test
# Out:
# 100%|██████████| 7442/7442 [00:02<00:00, 3624.89it/s]
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2526695    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2526698    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2526699    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  assessmentItemCode  testClass  testCode  solvingtime  \
# 0                7224                   1          6         1            3
# 1                7225                   2          6         1            8
# 2                7225                   3          6         1            7
# 3                7225                   4          6         1            7
# 4                7225                   5          6         1           11
# ...               ...                 ...        ...       ...          ...
# 2526695           438                   5          3        71           60
# 2526696          8836                   1          4       165           11
# 2526697          8836                   2          4       165           46
# 2526698          8836                   3          4       165           73
# 2526699          8836                   4          4       165           60
#
#          trend_solvingtime  seasonal_solvingtime  resid_solvingtime  \
# 0                53.914628            -54.685377       3.770749e+00
# 1                54.018292            -47.133404       1.115112e+00
# 2                54.122052            -30.645419      -1.647663e+01
# 3                54.225885            -42.518931      -4.706954e+00
# 4                54.329777            -57.067813       1.373804e+01
# ...                    ...                   ...                ...
# 2526695          29.708316             30.291684       1.065814e-14
# 2526696          29.708316            -18.708316       0.000000e+00
# 2526697          29.708316             16.291684       7.105427e-15
# 2526698          29.708316             43.291684       0.000000e+00
# 2526699          29.708316             30.291684       7.105427e-15
#
#          user_solvingtime_avg  user_answer_cumsum_prev  \
# 0                   43.547651                      0.0
# 1                   43.547651                      1.0
# 2                   43.547651                      2.0
# 3                   43.547651                      3.0
# 4                   43.547651                      4.0
# ...                       ...                      ...
# 2526695             52.222222                      1.0
# 2526696             52.222222                      1.0
# 2526697             52.222222                      2.0
# 2526698             52.222222                      3.0
# 2526699             52.222222                      4.0
#
#          user_answer_cumcount_prev  user_answerRatio_cum_prev
# 0                                0                   0.000000
# 1                                1                   1.000000
# 2                                2                   1.000000
# 3                                3                   1.000000
# 4                                4                   1.000000
# ...                            ...                        ...
# 2526695                          4                   0.250000
# 2526696                          5                   0.200000
# 2526697                          6                   0.333333
# 2526698                          7                   0.428571
# 2526699                          8                   0.500000
#
# [2526700 rows x 17 columns]

# %%
for_test = extract_datetime(for_test)
train = for_test.loc[for_test['answerCode'] != -1]
test = for_test.loc[for_test['answerCode'] == -1]
train
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2526695    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2526698    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2526699    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag  assessmentItemCode  testClass  testCode  solvingtime  \
# 0                7224                   1          6         1            3
# 1                7225                   2          6         1            8
# 2                7225                   3          6         1            7
# 3                7225                   4          6         1            7
# 4                7225                   5          6         1           11
# ...               ...                 ...        ...       ...          ...
# 2526695           438                   5          3        71           60
# 2526696          8836                   1          4       165           11
# 2526697          8836                   2          4       165           46
# 2526698          8836                   3          4       165           73
# 2526699          8836                   4          4       165           60
#
#          ...  resid_solvingtime  user_solvingtime_avg  \
# 0        ...       3.770749e+00             43.547651
# 1        ...       1.115112e+00             43.547651
# 2        ...      -1.647663e+01             43.547651
# 3        ...      -4.706954e+00             43.547651
# 4        ...       1.373804e+01             43.547651
# ...      ...                ...                   ...
# 2526695  ...       1.065814e-14             52.222222
# 2526696  ...       0.000000e+00             52.222222
# 2526697  ...       7.105427e-15             52.222222
# 2526698  ...       0.000000e+00             52.222222
# 2526699  ...       7.105427e-15             52.222222
#
#          user_answer_cumsum_prev  user_answer_cumcount_prev  \
# 0                            0.0                          0
# 1                            1.0                          1
# 2                            2.0                          2
# 3                            3.0                          3
# 4                            4.0                          4
# ...                          ...                        ...
# 2526695                      1.0                          4
# 2526696                      1.0                          5
# 2526697                      2.0                          6
# 2526698                      3.0                          7
# 2526699                      4.0                          8
#
#          user_answerRatio_cum_prev  month  day  hour  minute  second
# 0                         0.000000      3   24     0      17      11
# 1                         1.000000      3   24     0      17      14
# 2                         1.000000      3   24     0      17      22
# 3                         1.000000      3   24     0      17      29
# 4                         1.000000      3   24     0      17      36
# ...                            ...    ...  ...   ...     ...     ...
# 2526695                   0.250000      6    5     6      50      21
# 2526696                   0.200000      8   21     1       6      39
# 2526697                   0.333333      8   21     1       6      50
# 2526698                   0.428571      8   21     1       7      36
# 2526699                   0.500000      8   21     1       8      49
#
# [2525956 rows x 22 columns]

# %%
train.to_csv("new_train.csv", index=False)
test.to_csv("new_test.csv", index=False)
