# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
catboost = pd.read_csv("./output/catboost_clf_ms_data.csv").rename({'prediction':'prediction_catboost'}, axis=1)
bert = pd.read_csv("./output/model_bert_best2.csv").rename({'prediction':'prediction_bert'}, axis=1)
lightgcn = pd.read_csv("./output/lightgcn_best.csv").rename({'prediction':'prediction_lightgcn'}, axis=1)
subs = pd.concat([catboost, bert.drop(['id'], axis=1), lightgcn.drop(['id'], axis=1)], axis=1)

test = pd.read_csv("../../data/test_feature_engineering.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
subs['cat_bert'] = subs.iloc[:,1:3].apply(lambda x: abs(x[0]-x[1]), axis=1)

# %%
subs.cat_bert.plot(kind="hist", bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
subs[subs['cat_bert']>0.15].shape
# Out:
# (99, 5)

# %%
99/subs.shape[0]
# Out:
# 0.13306451612903225

# %%
id2idex = {v: i for i, v in enumerate(test.userID.unique())}
test['userID'] = test['userID'].map(id2idex)

# %%
test['high_diff'] = 0
test.loc[test['userID'].isin(subs[subs['cat_bert']>0.15].id), 'high_diff'] = 1

# %%
test
# Out:
#         userID assessmentItemID      testId  answerCode            Timestamp  \
# 0            0       A050023001  A050000023           1  2020-01-09 10:56:31
# 1            0       A050023002  A050000023           1  2020-01-09 10:56:57
# 2            0       A050023003  A050000023           0  2020-01-09 10:58:31
# 3            0       A050023004  A050000023           0  2020-01-09 10:58:36
# 4            0       A050023006  A050000023           0  2020-01-09 10:58:43
# ...        ...              ...         ...         ...                  ...
# 260109     743       A040130001  A040000130           0  2020-10-14 23:07:23
# 260110     743       A040130002  A040000130           1  2020-10-14 23:07:41
# 260111     743       A040130003  A040000130           1  2020-10-14 23:08:02
# 260112     743       A040130004  A040000130           1  2020-10-14 23:09:31
# 260113     743       A040130005  A040000130          -1  2020-10-14 23:10:03
#
#         KnowledgeTag  assessmentItemID_last  testId_first  testId_last  \
# 0               2626                      1             5           23
# 1               2626                      2             5           23
# 2               2625                      3             5           23
# 3               2625                      4             5           23
# 4               2623                      6             5           23
# ...              ...                    ...           ...          ...
# 260109          8832                      1             4          130
# 260110          8832                      2             4          130
# 260111          8244                      3             4          130
# 260112          8244                      4             4          130
# 260113          8832                      5             4          130
#
#          elapsed  ...  prior_quest_count  prior_ac_accuracy  \
# 0       0.000000  ...           0.000000           0.000000
# 1       3.295837  ...           0.693147           1.000000
# 2       4.553877  ...           1.098612           1.000000
# 3       1.791759  ...           1.386294           0.666667
# 4       2.079442  ...           1.609438           0.500000
# ...          ...  ...                ...                ...
# 260109  0.000000  ...           2.484907           0.727273
# 260110  2.944439  ...           2.564949           0.666667
# 260111  3.091042  ...           2.639057           0.692308
# 260112  4.499810  ...           2.708050           0.714286
# 260113  3.496508  ...           2.772589           0.733333
#
#         prior_relative_ac_sum  prior_relative_accuracy  \
# 0                    0.000000                 0.000000
# 1                    0.340000                 0.340000
# 2                    0.720000                 0.360000
# 3                    0.172000                 0.057333
# 4                   -0.464000                -0.116000
# ...                       ...                      ...
# 260109              -0.786353                -0.071487
# 260110              -1.223020                -0.101918
# 260111              -0.706353                -0.054335
# 260112              -0.553020                -0.039501
# 260113              -0.383020                -0.025535
#
#         prior_assessment_frequency  prior_test_frequency  \
# 0                              0.0              0.000000
# 1                              0.0              0.693147
# 2                              0.0              1.098612
# 3                              0.0              1.386294
# 4                              0.0              1.609438
# ...                            ...                   ...
# 260109                         0.0              0.000000
# 260110                         0.0              0.693147
# 260111                         0.0              1.098612
# 260112                         0.0              1.386294
# 260113                         0.0              1.609438
#
#         prior_tags_frequency  diff_time_btw_tags  prev_tag_answer  high_diff
# 0                   0.000000           17.086642              0.0          0
# 1                   0.693147            3.295837              1.0          0
# 2                   0.000000           17.086642              0.0          0
# 3                   0.693147            1.791759              0.0          0
# 4                   0.000000           17.086642              0.0          0
# ...                      ...                 ...              ...        ...
# 260109              0.000000           17.086642              0.0          0
# 260110              0.693147            2.944439              0.0          0
# 260111              0.000000           17.086642              0.0          0
# 260112              0.693147            4.499810              1.0          0
# 260113              1.098612            4.962845              1.0          0
#
# [260114 rows x 28 columns]

# %%
fig, axes = plt.subplots(1,2)
sns.countplot(x='assessmentItemID_last', data=test[test.high_diff==0], ax=axes[0])
sns.countplot(x='assessmentItemID_last', data=test[test.high_diff==1], ax=axes[1])
# Out:
# <AxesSubplot: xlabel='assessmentItemID_last', ylabel='count'>

# %%
fig, axes = plt.subplots(1,2)
sns.countplot(x='testId_first', data=test[test.high_diff==0], ax=axes[0])
sns.countplot(x='testId_first', data=test[test.high_diff==1], ax=axes[1])
# Out:
# <AxesSubplot: xlabel='testId_first', ylabel='count'>

# %%
cont_cols = [
    'elapsed', 'accuracy_by_assessment', 'accuracy_by_test',
    'accuracy_by_tag', 'accuracy_by_assessment_last',
    'accuracy_by_test_first', 'accuracy_by_test_last',
    'prior_ac_count', 'prior_quest_count',
    'prior_ac_accuracy', 'prior_relative_ac_sum', 'prior_relative_accuracy',
    'prior_assessment_frequency', 'prior_test_frequency',
    'prior_tags_frequency', 'diff_time_btw_tags', 'prev_tag_answer',
]

# %%
len(cont_cols)
# Out:
# 17

# %%
c
# Out:
# 'elapsed'

# %%
i
# Out:
# 0

# %%
fig, axes = plt.subplots(1,2, figsize=(16, 8))
sns.histplot(x=c, data=test[test.high_diff==0], ax=axes[2*i])
sns.histplot(x=c, data=test[test.high_diff==1], ax=axes[2*i+1])
# Out:
# <AxesSubplot: xlabel='elapsed', ylabel='Count'>

# %%
fig, axes = plt.subplots(17,2, figsize=(16, 8*17))
for i, c in enumerate(cont_cols):
    sns.histplot(x=c, data=test[test.high_diff==0], ax=axes[i][0])
    sns.histplot(x=c, data=test[test.high_diff==1], ax=axes[i][1])

# %%
import pandas as pd
import numpy as np
from numpy import dot
from numpy.linalg import norm

def cos_sim(A, B):
  return dot(A, B)/(norm(A)*norm(B))

# %%
lightgcn = pd.read_csv("./output/lightgcn_best.csv")
catboost_clf_ms_data = pd.read_csv("./output/catboost_clf_ms_data.csv")
lgbmregressor_ms_data = pd.read_csv("./output/lgbmregressor_ms_data.csv")
tabnet805 = pd.read_csv("./output/tabnet805.csv")
stack = pd.read_csv("./output/stack.csv")
catboost_pkt = pd.read_csv("./output/catboost_pkt.csv")
lstmattn_best_sigmoid = pd.read_csv("./output/lstmattn_best_sigmoid.csv")
model_lstm_best2 = pd.read_csv("./output/model_lstm_best2.csv")
model_lstmattn_best2 = pd.read_csv("./output/model_lstmattn_best2.csv")
model_bert_best2 = pd.read_csv("./output/model_bert_best2.csv")

# %%
col_names = [
    'lightgcn', 'catboost_clf_ms_data', 'lgbmregressor_ms_data', 'tabnet805', 'stack',
    'catboost_pkt', 'lstmattn_best_sigmoid', 
    'model_lstm_best2', 'model_lstmattn_best2', 'model_bert_best2'
]

# %%
concat = pd.concat([
    lightgcn['prediction'],
    catboost_clf_ms_data['prediction'], lgbmregressor_ms_data['prediction'], tabnet805['prediction'],
    stack['prediction'], catboost_pkt['prediction'], lstmattn_best_sigmoid['prediction'], 
    model_lstm_best2['prediction'], model_lstmattn_best2['prediction'], model_bert_best2['prediction']
], axis=1)
concat.columns = col_names

# %%
for c1 in concat.items():
    for c2  in concat.items():
        print(c1[0], c2[0])
        print(cos_sim(c1[1], c2[1]))
        print()
# Out:
# lightgcn lightgcn
# 0.9999999999999999
#
# lightgcn catboost_clf_ms_data
# 0.9608819456400504
#
# lightgcn lgbmregressor_ms_data
# 0.9551959147173607
#
# lightgcn tabnet805
# 0.9312645498561262
#
# lightgcn stack
# 0.9480131858430213
#
# lightgcn catboost_pkt
# 0.9518201229223361
#
# lightgcn lstmattn_best_sigmoid
# 0.9135551250958991
#
# lightgcn model_lstm_best2
# 0.9563625595460318
#
# lightgcn model_lstmattn_best2
# 0.9556797729168003
#
# lightgcn model_bert_best2
# 0.9507518330364443
#
# catboost_clf_ms_data lightgcn
# 0.9608819456400504
#
# catboost_clf_ms_data catboost_clf_ms_data
# 0.9999999999999999
#
# catboost_clf_ms_data lgbmregressor_ms_data
# 0.9811111639137367
#
# catboost_clf_ms_data tabnet805
# 0.9640743913634148
#
# catboost_clf_ms_data stack
# 0.9790184214936714
#
# catboost_clf_ms_data catboost_pkt
# 0.9808938481974169
#
# catboost_clf_ms_data lstmattn_best_sigmoid
# 0.9425385016590714
#
# catboost_clf_ms_data model_lstm_best2
# 0.9837314457429936
#
# catboost_clf_ms_data model_lstmattn_best2
# 0.9861278092087639
#
# catboost_clf_ms_data model_bert_best2
# 0.984294138431217
#
# lgbmregressor_ms_data lightgcn
# 0.9551959147173607
#
# lgbmregressor_ms_data catboost_clf_ms_data
# 0.9811111639137367
#
# lgbmregressor_ms_data lgbmregressor_ms_data
# 1.0
#
# lgbmregressor_ms_data tabnet805
# 0.9687268510908151
#
# lgbmregressor_ms_data stack
# 0.9848268769895756
#
# lgbmregressor_ms_data catboost_pkt
# 0.9859870771381417
#
# lgbmregressor_ms_data lstmattn_best_sigmoid
# 0.9386683077248067
#
# lgbmregressor_ms_data model_lstm_best2
# 0.9835637646353353
#
# lgbmregressor_ms_data model_lstmattn_best2
# 0.9838756458634468
#
# lgbmregressor_ms_data model_bert_best2
# 0.9843540016563671
#
# tabnet805 lightgcn
# 0.9312645498561262
#
# tabnet805 catboost_clf_ms_data
# 0.9640743913634148
#
# tabnet805 lgbmregressor_ms_data
# 0.9687268510908151
#
# tabnet805 tabnet805
# 1.0
#
# tabnet805 stack
# 0.9765594061390033
#
# tabnet805 catboost_pkt
# 0.9808614288192864
#
# tabnet805 lstmattn_best_sigmoid
# 0.9171046543634331
#
# tabnet805 model_lstm_best2
# 0.9704680283384077
#
# tabnet805 model_lstmattn_best2
# 0.9678089167322381
#
# tabnet805 model_bert_best2
# 0.9742137774131241
#
# stack lightgcn
# 0.9480131858430213
#
# stack catboost_clf_ms_data
# 0.9790184214936714
#
# stack lgbmregressor_ms_data
# 0.9848268769895756
#
# stack tabnet805
# 0.9765594061390033
#
# stack stack
# 1.0
#
# stack catboost_pkt
# 0.9964710976333534
#
# stack lstmattn_best_sigmoid
# 0.9355804464420044
#
# stack model_lstm_best2
# 0.9883007901705901
#
# stack model_lstmattn_best2
# 0.9870989220458493
#
# stack model_bert_best2
# 0.9880724709885464
#
# catboost_pkt lightgcn
# 0.9518201229223361
#
# catboost_pkt catboost_clf_ms_data
# 0.9808938481974169
#
# catboost_pkt lgbmregressor_ms_data
# 0.9859870771381417
#
# catboost_pkt tabnet805
# 0.9808614288192864
#
# catboost_pkt stack
# 0.9964710976333534
#
# catboost_pkt catboost_pkt
# 1.0000000000000002
#
# catboost_pkt lstmattn_best_sigmoid
# 0.9393867825644336
#
# catboost_pkt model_lstm_best2
# 0.9899855543184514
#
# catboost_pkt model_lstmattn_best2
# 0.9894318802691745
#
# catboost_pkt model_bert_best2
# 0.9904949144910308
#
# lstmattn_best_sigmoid lightgcn
# 0.9135551250958991
#
# lstmattn_best_sigmoid catboost_clf_ms_data
# 0.9425385016590714
#
# lstmattn_best_sigmoid lgbmregressor_ms_data
# 0.9386683077248067
#
# lstmattn_best_sigmoid tabnet805
# 0.9171046543634331
#
# lstmattn_best_sigmoid stack
# 0.9355804464420044
#
# lstmattn_best_sigmoid catboost_pkt
# 0.9393867825644336
#
# lstmattn_best_sigmoid lstmattn_best_sigmoid
# 1.0000000000000002
#
# lstmattn_best_sigmoid model_lstm_best2
# 0.9492479608618967
#
# lstmattn_best_sigmoid model_lstmattn_best2
# 0.9491601507981708
#
# lstmattn_best_sigmoid model_bert_best2
# 0.9439799052144165
#
# model_lstm_best2 lightgcn
# 0.9563625595460318
#
# model_lstm_best2 catboost_clf_ms_data
# 0.9837314457429936
#
# model_lstm_best2 lgbmregressor_ms_data
# 0.9835637646353353
#
# model_lstm_best2 tabnet805
# 0.9704680283384077
#
# model_lstm_best2 stack
# 0.9883007901705901
#
# model_lstm_best2 catboost_pkt
# 0.9899855543184514
#
# model_lstm_best2 lstmattn_best_sigmoid
# 0.9492479608618967
#
# model_lstm_best2 model_lstm_best2
# 1.0
#
# model_lstm_best2 model_lstmattn_best2
# 0.9924083085327302
#
# model_lstm_best2 model_bert_best2
# 0.9912114241143967
#
# model_lstmattn_best2 lightgcn
# 0.9556797729168003
#
# model_lstmattn_best2 catboost_clf_ms_data
# 0.9861278092087639
#
# model_lstmattn_best2 lgbmregressor_ms_data
# 0.9838756458634468
#
# model_lstmattn_best2 tabnet805
# 0.9678089167322381
#
# model_lstmattn_best2 stack
# 0.9870989220458493
#
# model_lstmattn_best2 catboost_pkt
# 0.9894318802691745
#
# model_lstmattn_best2 lstmattn_best_sigmoid
# 0.9491601507981708
#
# model_lstmattn_best2 model_lstm_best2
# 0.9924083085327302
#
# model_lstmattn_best2 model_lstmattn_best2
# 1.0
#
# model_lstmattn_best2 model_bert_best2
# 0.9944593675789737
#
# model_bert_best2 lightgcn
# 0.9507518330364443
#
# model_bert_best2 catboost_clf_ms_data
# 0.984294138431217
#
# model_bert_best2 lgbmregressor_ms_data
# 0.9843540016563671
#
# model_bert_best2 tabnet805
# 0.9742137774131241
#
# model_bert_best2 stack
# 0.9880724709885464
#
# model_bert_best2 catboost_pkt
# 0.9904949144910308
#
# model_bert_best2 lstmattn_best_sigmoid
# 0.9439799052144165
#
# model_bert_best2 model_lstm_best2
# 0.9912114241143967
#
# model_bert_best2 model_lstmattn_best2
# 0.9944593675789737
#
# model_bert_best2 model_bert_best2
# 1.0000000000000002

# %%
1/3*0.25+1/3*0.5+0.25*1/3 +1/3*0.25+1/3*0.25+1/3*0.25+1/3*0.25+1/3*0.2+0.25*1/3+1/3*0.3+0.25*1/3
# Out:
# 1.0
